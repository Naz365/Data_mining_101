# %%
import pandas as pd
import numpy as np


df = pd.DataFrame({'Age': [42, 15, 67, 55, 1, 29, 75, 89, 4,
9 ,10, 15, 38, 22, 77]})


print(df)
# Out:
#     Age
# 0    42
# 1    15
# 2    67
# 3    55
# 4     1
# 5    29
# 6    75
# 7    89
# 8     4
# 9     9
# 10   10
# 11   15
# 12   38
# 13   22
# 14   77
