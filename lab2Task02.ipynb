# %% [markdown]
# <a href="https://colab.research.google.com/github/Naz365/dataMIning424/blob/master/lab2Task02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
simpleText = """ Contrary to popular belief, Lorem Ipsum is not simply random text, It has roots in a piece of classical Latin literature from 45 BC, making it over 2000 years old. Richard McClintock, a Latin professor at Hampden-Sydney College in Virginia, looked up one of the more obscure Latin words, consectetur, from a Lorem Ipsum passage, and going through the cites of the word in classical literature, discovered the undoubtable source. Lorem Ipsum comes from sections 1.10.32 and 1.10.33 of "de Finibus Bonorum et Malorum" (The Extremes of Good and Evil) by Cicero, written in 45 BC. This book is a treatise on the theory of ethics, very popular during the Renaissance. The first line of Lorem Ipsum, "Lorem ipsum dolor sit amet..", comes from a line in section 1.10.32.

The standard chunk of Lorem Ipsum used since the 1500s is reproduced below for thosem, interested. Sections 1.10.32 and 1.10.33 from "de Finibus Bonorum et Malorum" by Cicero are also reproduced in their exact original form, accompanied by English versions from the 1914 translation by H. Rackham. """

# %%
print(simpleText)
# Out:
#  Contrary to popular belief, Lorem Ipsum is not simply random text, It has roots in a piece of classical Latin literature from 45 BC, making it over 2000 years old. Richard McClintock, a Latin professor at Hampden-Sydney College in Virginia, looked up one of the more obscure Latin words, consectetur, from a Lorem Ipsum passage, and going through the cites of the word in classical literature, discovered the undoubtable source. Lorem Ipsum comes from sections 1.10.32 and 1.10.33 of "de Finibus Bonorum et Malorum" (The Extremes of Good and Evil) by Cicero, written in 45 BC. This book is a treatise on the theory of ethics, very popular during the Renaissance. The first line of Lorem Ipsum, "Lorem ipsum dolor sit amet..", comes from a line in section 1.10.32.
#
# ...

# %%
newSimpleText=[]
for i in simpleText:
  newSimpleText.append(i.split(','))

# %%
newSimpleText
# Out:
# [[' '],
#  ['C'],
#  ['o'],
#  ['n'],
#  ['t'],
#  ['r'],
#  ['a'],
#  ['r'],
#  ['y'],
#  [' '],
#  ['t'],
#  ['o'],
#  [' '],
#  ['p'],
#  ['o'],
#  ['p'],
#  ['u'],
#  ['l'],
#  ['a'],
#  ['r'],
#  [' '],
#  ['b'],
#  ['e'],
#  ['l'],
#  ['i'],
#  ['e'],
#  ['f'],
#  ['', ''],
#  [' '],
#  ['L'],
#  ['o'],
#  ['r'],
#  ['e'],
#  ['m'],
#  [' '],
#  ['I'],
#  ['p'],
#  ['s'],
#  ['u'],
#  ['m'],
#  [' '],
#  ['i'],
#  ['s'],
#  [' '],
#  ['n'],
#  ['o'],
#  ['t'],
#  [' '],
#  ['s'],
#  ['i'],
#  ['m'],
#  ['p'],
#  ['l'],
#  ['y'],
#  [' '],
#  ['r'],
#  ['a'],
#  ['n'],
#  ['d'],
#  ['o'],
#  ['m'],
#  [' '],
#  ['t'],
#  ['e'],
#  ['x'],
#  ['t'],
#  ['', ''],
#  [' '],
#  ['I'],
#  ['t'],
#  [' '],
#  ['h'],
#  ['a'],
#  ['s'],
#  [' '],
#  ['r'],
#  ['o'],
#  ['o'],
#  ['t'],
#  ['s'],
#  [' '],
#  ['i'],
#  ['n'],
#  [' '],
#  ['a'],
#  [' '],
#  ['p'],
#  ['i'],
#  ['e'],
#  ['c'],
#  ['e'],
#  [' '],
#  ['o'],
#  ['f'],
#  [' '],
#  ['c'],
#  ['l'],
#  ['a'],
#  ['s'],
# ...
